# %% [markdown]
# <a href="https://colab.research.google.com/github/Yennyarte/DSND_Term2/blob/master/Tendencias_de_empleo_en_Canad%C3%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
datos = files.upload()
# Out:
#      <input type="file" id="files-c1cb2410-f36f-4329-b27e-ccc87657574f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1cb2410-f36f-4329-b27e-ccc87657574f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
df=pd.read_csv("empleo.csv")
df.head()
# Out:
# <ipython-input-6-803bde0ae8fa>:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("empleo.csv")
#   REF_DATE     GEO           DGUID  \
# 0  1976-01  Canada  2016A000011124
# 1  1976-01  Canada  2016A000011124
# 2  1976-01  Canada  2016A000011124
# 3  1976-01  Canada  2016A000011124
# 4  1976-01  Canada  2016A000011124
#
#   North American Industry Classification System (NAICS)  \
# 0                     Total employed, all industries
# 1                     Total employed, all industries
# 2                     Total employed, all industries
# 3                     Total employed, all industries
# 4                     Total employed, all industries
#
#                                 Statistics            Data type      UOM  \
# 0                                 Estimate  Seasonally adjusted  Persons
# 1                                 Estimate          Trend-cycle  Persons
# ...

# %%
df.shape
# Out:
# (600096, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600096 entries, 0 to 600095
# Data columns (total 17 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   REF_DATE                                               600096 non-null  object
#  1   GEO                                                    600096 non-null  object
#  2   DGUID                                                  600096 non-null  object
#  3   North American Industry Classification System (NAICS)  600096 non-null  object
#  4   Statistics                                             600096 non-null  object
#  5   Data type                                              600096 non-null  object
#  6   UOM                                                    600096 non-null  object
#  7   UOM_ID                                                 600096 non-null  int64
# ...
